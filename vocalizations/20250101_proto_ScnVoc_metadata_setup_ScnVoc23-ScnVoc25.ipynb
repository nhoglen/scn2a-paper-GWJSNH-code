# %%
import numpy as np
import pandas as pd
import os
from nwb_utils import *
from behavior_error_checks import *
from vak_utils import convert_time_with_offset

# %%
# ----- Set up paths and files -----
cohort_tag = 'ScnVoc'

rootpath = 'M:\\scn2a-paper-GWJSNH'

nwbfile_path = os.path.join(rootpath,f'{cohort_tag}_nwb')
analysis_path = os.path.join(rootpath,f'{cohort_tag}_analysis')
acq_path = os.path.join(rootpath,f'{cohort_tag}_acquisition')
pred_path = os.path.join(rootpath,f'{cohort_tag}_predictions')
paths = [nwbfile_path,analysis_path,acq_path,pred_path]
for pathi in paths:
    if not os.path.isdir(pathi):
        os.makedirs(pathi)

metafile = 'metadata_ScnVoc_20250225.csv'
meta = pd.read_csv(os.path.join(analysis_path,metafile),sep=',')

meta.head()
# Out:
#     PairTag     AssayType   RecDate  RecSession  RecSlot RecTime  \
# 0  ScnVoc23  introduction  20250109           1        1   13:51
# 1  ScnVoc24  introduction  20250109           1        1   13:51
# 2  ScnVoc25  introduction  20250109           1        2   14:35
#
#                  VideoFile  VideoPath VideoSide  ScoreFile  ...  ScoredBy  \
# 0  2025-01-09_13-51-11.flv        NaN         L        NaN  ...       NaN
# 1  2025-01-09_13-51-11.flv        NaN         R        NaN  ...       NaN
# 2  2025-01-09_14-35-41.flv        NaN         L        NaN  ...       NaN
#
#   FullTimeline  Pups FocalColor StrangerID StrangerGT  PPTlane PartnerChamber  \
# 0         True   NaN  [0, 0, 0]        NaN        NaN      NaN            NaN
# 1         True   NaN  [0, 0, 0]        NaN        NaN      NaN            NaN
# 2         True   NaN  [0, 0, 0]        NaN        NaN      NaN            NaN
#
#   UseAssay Notes
# 0     True   NaN
# 1     True   NaN
# 2     True   NaN
#
# [3 rows x 47 columns]

# %%
# ----- Start times for sound files -----
audstarts = convert_time_with_offset(meta.VideoSyncPoint1,meta.VideoAssayStart,meta.AudioSyncPoint1)
meta.AudioAssayStart = audstarts

# %%
meta.to_csv('metadata_ScnVoc_20250225.csv',index=False)
